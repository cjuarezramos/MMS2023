# %%
# importar librerias que necesito
import numpy as np
import matplotlib.pyplot as plt

# %%
# constantes
D = 1 #kg/s
m = 1 #kg
v0 = 5 # m/s

# %%
t=np.arange(0,10,2)
v = v0*np.exp(-D/m*t)

# %%
plt.plot(t,v)
