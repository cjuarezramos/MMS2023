# %%
# Problema de Sistema masa resorte amortiguador
# importar librerias
import numpy as np
import matplotlib.pyplot as plt

# %%
# Constantes del sistema
M = 1 # kg
c = 5 # kg/s
k = 1 # kg/s^2

# %%
t = np.arange(0,10,0.01)

# %%
# condiciones iniciales
x0 = 1
v0 = 0

# %%
p1 = -c/(2*M)+1*np.sqrt(1*pow(c/(2*M),2)-k/M)
print(p1)
# Out:
# -0.20871215252208009

# %%
p2 = -c/(2*M)-1*np.sqrt(1*pow(c/(2*M),2)-k/M)
print(p2)
# Out:
# -4.7912878474779195

# %%
A1 = (x0*p2-v0)/(p2-p1)
print(A1)
# Out:
# 1.045544725589981

# %%
A2 = (v0-p1*x0)/(p2-p1)
print(A2)
# Out:
# -0.04554472558998098

# %%
x = A1*np.exp(p1*t)+A2*np.exp(p2*t)

plt.plot(t,x)
